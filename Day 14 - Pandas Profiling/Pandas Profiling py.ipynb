# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_dataset = ("https://raw.githubusercontent.com/campusx-official/100-days-of-machine-learning/main/day19-understanding-your-data-descriptive-stats/train.csv")

# %% [markdown]
# ## Loading Dataset

# %%
titanic = pd.read_csv(train_dataset)
titanic.sample(5)
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 544          545         0       1    Douglas, Mr. Walter Donald    male
# 677          678         1       3       Turja, Miss. Anna Sofia  female
# 598          599         0       3             Boulos, Mr. Hanna    male
# 798          799         0       3  Ibrahim Shawah, Mr. Yousseff    male
# 26            27         0       3       Emir, Mr. Farred Chehab    male
#
#       Age  SibSp  Parch    Ticket      Fare Cabin Embarked
# 544  50.0      1      0  PC 17761  106.4250   C86        C
# 677  18.0      0      0      4138    9.8417   NaN        S
# 598   NaN      0      0      2664    7.2250   NaN        C
# 798  30.0      0      0      2685    7.2292   NaN        C
# 26    NaN      0      0      2631    7.2250   NaN        C

# %%
# !pip install pandas-profiling==3.2.0 pydantic<2.0
# Out:
# The system cannot find the file specified.

# %%
# !pip install ydata-profiling
# Out:
# ...
#      ---------------------------------------- 0.0/109.4 kB ? eta -:--:--
#      ---------------------------------------- 0.0/109.4 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/109.4 kB ? eta -:--:--
#      ---------- -------------------------- 30.7/109.4 kB 435.7 kB/s eta 0:00:01
#      ------------------------------- ----- 92.2/109.4 kB 871.5 kB/s eta 0:00:01
#      ------------------------------------ 109.4/109.4 kB 793.6 kB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/359.5 kB ? eta -:--:--
#    ------ --------------------------------- 61.4/359.5 kB 1.7 MB/s eta 0:00:01
#    -------------------------- ------------- 235.5/359.5 kB 2.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 317.4/359.5 kB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 359.5/359.5 kB 2.2 MB/s eta 0:00:00
# ...

# %%
from ydata_profiling import ProfileReport

# Assuming df is your dataframe
prof = ProfileReport(titanic)
prof.to_file(output_file='EDA_Report.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# c:\Users\mhatr\anaconda3\Lib\site-packages\ydata_profiling\model\correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'could not convert string to float: 'S'')
#   warnings.warn(
# c:\Users\mhatr\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
# c:\Users\mhatr\anaconda3\Lib\site-packages\ydata_profiling\model\missing.py:78: UserWarning: There was an attempt to generate the Heatmap missing values diagrams, but this failed.
# ...
